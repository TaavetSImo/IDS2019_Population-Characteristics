# %%
import pandas as pd
import numpy as np

# %%
my_cols = [str(i) for i in range(65)] # create some row names
data = pd.read_csv('Urbbpop.csv',names=my_cols,header=None, engine="python")

df = data.copy()

df1 = df.iloc[2:]
df1.reset_index(drop=True, inplace=True)



#dropime ebavajalikud indikaatorid 
df1.drop(df1.iloc[:, 1:4], inplace = True, axis = 1)


df1.head()
# Out:
#               0         4         5         6         7         8         9  \
# 0  Country Name    1960.0    1961.0    1962.0    1963.0    1964.0    1965.0
# 1         Aruba   27526.0   28141.0   28532.0   28761.0   28924.0   29082.0
# 2   Afghanistan  755836.0  796272.0  839385.0  885228.0  934135.0  986074.0
# 3        Angola  569222.0  597288.0  628381.0  660180.0  691532.0  721552.0
# 4       Albania  493982.0  513592.0  530766.0  547928.0  565248.0  582374.0
#
#           10         11         12  ...          55          56          57  \
# 0     1966.0     1967.0     1968.0  ...      2011.0      2012.0      2013.0
# 1    29253.0    29416.0    29575.0  ...     43819.0     44057.0     44348.0
# 2  1041191.0  1099272.0  1161355.0  ...   7212518.0   7528588.0   7865067.0
# 3   749534.0   776116.0   804107.0  ...  14660282.0  15383127.0  16130304.0
# 4   599300.0   616687.0   635924.0  ...   1546929.0   1575788.0   1603505.0
#
# ...

# %%
df2 = df1.T.set_index(0).T


df2.head()
# Out:
# 0 Country Name  1960.0  1961.0  1962.0  1963.0  1964.0  1965.0       1966.0  \
# 1        Aruba   27526   28141   28532   28761   28924   29082        29253
# 2  Afghanistan  755836  796272  839385  885228  934135  986074  1.04119e+06
# 3       Angola  569222  597288  628381  660180  691532  721552       749534
# 4      Albania  493982  513592  530766  547928  565248  582374       599300
# 5      Andorra    7839    8766    9754   10811   11915   13067        14262
#
# 0       1967.0       1968.0  ...       2011.0       2012.0       2013.0  \
# 1        29416        29575  ...        43819        44057        44348
# 2  1.09927e+06  1.16136e+06  ...  7.21252e+06  7.52859e+06  7.86507e+06
# 3       776116       804107  ...  1.46603e+07  1.53831e+07  1.61303e+07
# 4       616687       635924  ...  1.54693e+06  1.57579e+06  1.60350e+06
# 5        15494        16765  ...        74305        73056        71515
#
# ...

# %%
#Transpose DateFrame - Columns to rows
df_t = df2.T


#1st row to header
df_t.index.names = [None]
new_header = df_t.iloc[0]
df_t = df_t[1:]
df_t.columns = new_header


df_t.head(10)
# Out:
# Country Name  Aruba  Afghanistan  Angola Albania Andorra   Arab World  \
# 1960.0        27526       755836  569222  493982    7839  2.87972e+07
# 1961.0        28141       796272  597288  513592    8766  3.02928e+07
# 1962.0        28532       839385  628381  530766    9754  3.18567e+07
# 1963.0        28761       885228  660180  547928   10811   3.3513e+07
# 1964.0        28924       934135  691532  565248   11915  3.52753e+07
# 1965.0        29082       986074  721552  582374   13067  3.71639e+07
# 1966.0        29253  1.04119e+06  749534  599300   14262  3.90985e+07
# 1967.0        29416  1.09927e+06  776116  616687   15494  4.10011e+07
# 1968.0        29575  1.16136e+06  804107  635924   16765  4.29964e+07
# 1969.0        29738  1.22827e+06  837758  656733   18083  4.50727e+07
#
# Country Name United Arab Emirates    Argentina      Armenia American Samoa  \
# 1960.0                      67927  1.50768e+07       960956          13324
# ...

# %%
new = df_t.filter(['Norway','Estonia','Poland',
                   'Australia','Vanuatu','New Zealand',
                   'China','Vietnam','Georgia'], axis=1)

new.tail()
# Out:
# Country Name       Norway Estonia       Poland    Australia Vanuatu  \
# 2016.0        4.26535e+06  902145  2.28496e+07  2.07558e+07   69755
# 2017.0        4.32031e+06  905267  2.28248e+07   2.1134e+07   71843
# 2018.0        4.37094e+06  909825  2.28092e+07  2.14964e+07   73972
# 2019.0                NaN     NaN          NaN          NaN     NaN
# NaN                   NaN     NaN          NaN          NaN     NaN
#
# Country Name  New Zealand        China      Vietnam      Georgia
# 2016.0        4.05492e+06  7.82199e+08  3.23147e+07  2.15588e+06
# 2017.0        4.14509e+06  8.03555e+08  3.33103e+07  2.17085e+06
# 2018.0        4.22781e+06  8.23828e+08  3.43172e+07  2.18756e+06
# 2019.0                NaN          NaN          NaN          NaN
# NaN                   NaN          NaN          NaN          NaN

# %%
new.to_csv('noo.csv')

# %%
cols_plot = ['Norway','Estonia','Poland',
                   'Australia','Vanuatu','New Zealand',
                   'China','Vietnam','Georgia']
axes = new[cols_plot].plot(marker='.', alpha=0.5, figsize=(20, 18), subplots=True)
for ax in axes:
    ax.set_ylabel('Urban Population')
